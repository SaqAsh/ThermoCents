# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 6))

plt.plot(toronto_weather['date'], toronto_weather['tavg'], 
         label='Toronto', color='blue', linewidth=2)

plt.plot(chievres_weather['date'], chievres_weather['tavg'], 
         label='Chievres', color='red', linewidth=2)

plt.title('Temperature Comparison: Toronto vs Chievres')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()
